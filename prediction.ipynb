# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_new = pd.read_parquet("data_interm/df_final2224.parquet")
df_new
# Out:
#              Num_Acc  year    id_usager  id_vehicule num_veh  place  catu  \
# 0       202200000001  2022    1 099 700      813 952     A01    1.0     1
# 1       202200000001  2022    1 099 701      813 953     B01    1.0     1
# 2       202200000002  2022    1 099 698      813 950     B01    1.0     1
# 3       202200000002  2022    1 099 699      813 951     A01    1.0     1
# 4       202200000003  2022    1 099 696      813 948     A01    1.0     1
# ...              ...   ...          ...          ...     ...    ...   ...
# 377633  202400054401  2024  203 859 570  155 686 119     Y01    1.0     1
# 377634  202400054401  2024  203 859 572  155 686 120     A01    1.0     1
# 377635  202400054402  2024  203 859 569  155 686 118     A01    1.0     1
# 377636  202400054402  2024  203 859 571  155 686 121     B01    1.0     1
# 377637  202400054402  2024  203 859 574  155 686 123     C01    1.0     1
#
#         grav  sexe  an_nais  ...  lum  dep    com  agg  int atm  col  \
# ...
